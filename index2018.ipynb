# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
raw_data = pd.read_csv('Index2018.csv')
data = raw_data.copy()

# %%
data.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
data.describe()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
data.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %%
data['spx'].plot(title="S&P500 Prices",figsize=(20,5))
# Out:
# <AxesSubplot:title={'center':'S&P500 Prices'}>

# %%
data['ftse'].plot(title="FTSE100 Prices",figsize=(20,5))
# Out:
# <AxesSubplot:title={'center':'FTSE100 Prices'}>

# %%
data['spx'].plot(title="S&P500 Prices",figsize=(20,5))
data['ftse'].plot(title="FTSE100 Prices",figsize=(20,5))
plt.title("S&P v FTSE")
# Out:
# Text(0.5, 1.0, 'S&P v FTSE')

# %% [markdown]
# ## Quantile-Quantile QQ Plot  (used to determine whether a data set is distributed a certain way

# %%
import scipy.stats
import pylab

# %%
scipy.stats.probplot(data['spx'],plot=pylab)
pylab.show()
